# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
train_images = train_images.reshape((60000,28,28,1))
train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000,28,28,1))
test_images = test_images.astype('float32')/255

from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
train_labels.shape
# Out:
# (60000, 10)

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(32,(3,3), activation='relu', input_shape = (28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64,activation = 'relu'))
model.add(layers.Dense(10, activation= 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'rmsprop',
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size = 64)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a980f4ceed3b> in <module>
# ----> 1 model.fit(train_images, train_labels, epochs=5, batch_size = 64)
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
#    1159               if data_handler.should_sync:
#    1160                 context.async_wait()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     973           # TODO(mdan): Push this block higher in tf.function's call stack.
#     974           try:
# --> 975             return autograph.converted_call(
#     976                 original_func,
#     977                 args,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in tf__step_function(model, iterator)
#      27                         return fscope_1.ret(retval__1, do_return_1)
#      28                 data = ag__.converted_call(ag__.ld(next), (ag__.ld(iterator),), None, fscope)
# ---> 29                 outputs = ag__.converted_call(ag__.ld(model).distribute_strategy.run, (ag__.ld(run_step),), dict(args=(ag__.ld(data),)), fscope)
#      30                 outputs = ag__.converted_call(ag__.ld(reduce_per_replica), (ag__.ld(outputs), ag__.ld(self).distribute_strategy), dict(reduction='first'), fscope)
#      31                 ag__.converted_call(ag__.ld(write_scalar_summaries), (ag__.ld(outputs),), dict(step=ag__.ld(model)._train_counter), fscope)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1283       fn = autograph.tf_convert(
#    1284           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1285       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1286
#    1287   def reduce(self, reduce_op, value, axis):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2831       kwargs = {}
#    2832     with self._container_strategy().scope():
# -> 2833       return self._call_for_each_replica(fn, args, kwargs)
#    2834
#    2835   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3606   def _call_for_each_replica(self, fn, args, kwargs):
#    3607     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3608       return fn(*args, **kwargs)
#    3609
#    3610   def _reduce_to(self, reduce_op, value, destinations, options):
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in run_step(data)
#      16                         do_return_1 = False
#      17                         retval__1 = ag__.UndefinedReturnValue()
# ---> 18                         outputs = ag__.converted_call(ag__.ld(model).train_step, (ag__.ld(data),), None, fscope_1)
#      19                         with ag__.ld(tf).control_dependencies(ag__.ld(_minimum_control_deps)(ag__.ld(outputs))):
#      20                             ag__.converted_call(ag__.ld(model)._train_counter.assign_add, (1,), None, fscope_1)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in tf__train_step(self, data)
#      13                 with ag__.ld(tf).GradientTape() as tape:
#      14                     y_pred = ag__.converted_call(ag__.ld(self), (ag__.ld(x),), dict(training=True), fscope)
# ---> 15                     loss = ag__.converted_call(ag__.ld(self).compiled_loss, (ag__.ld(y), ag__.ld(y_pred), ag__.ld(sample_weight)), dict(regularization_losses=ag__.ld(self).losses), fscope)
#      16                 ag__.converted_call(ag__.ld(self).optimizer.minimize, (ag__.ld(loss), ag__.ld(self).trainable_variables), dict(tape=ag__.ld(tape)), fscope)
#      17                 ag__.converted_call(ag__.ld(self).compiled_metrics.update_state, (ag__.ld(y), ag__.ld(y_pred), ag__.ld(sample_weight)), None, fscope)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/compile_utils.py in tf____call__(self, y_true, y_pred, sample_weight, regularization_losses)
#     185                 y_t = ag__.Undefined('y_t')
#     186                 loss_obj = ag__.Undefined('loss_obj')
# --> 187                 ag__.for_stmt(ag__.converted_call(ag__.ld(zip), tuple(ag__.ld(zip_args)), None, fscope), None, loop_body, get_state_9, set_state_9, ('batch_dim',), {'iterate_names': '(y_t, y_p, sw, loss_obj, loss_weight, metric_obj)'})
#     188
#     189                 def get_state_10():
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     441
#     442   else:
# --> 443     _py_for_stmt(iter_, extra_test, body, None, None)
#     444
#     445
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     470   else:
#     471     for target in iter_:
# --> 472       body(target)
#     473
#     474
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     456     original_body = body
#     457     def protected_body(protected_iter):
# --> 458       original_body(protected_iter)
#     459       after_iteration()
#     460       before_iteration()
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/compile_utils.py in loop_body(itr)
#     175                         nonlocal sw, y_p, batch_dim, y_t
#     176                         pass
# --> 177                     ag__.if_stmt(ag__.not_(continue_), if_body_8, else_body_8, get_state_8, set_state_8, ('batch_dim', 'sw', 'y_p', 'y_t'), 1)
#     178                 sw = ag__.Undefined('sw')
#     179                 loss_value = ag__.Undefined('loss_value')
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/anaconda3/lib/python3.8/site-packages/keras/engine/compile_utils.py in if_body_8()
#      70                         nonlocal sw, y_p, batch_dim, y_t
#      71                         (y_t, y_p, sw) = ag__.converted_call(ag__.ld(match_dtype_and_rank), (ag__.ld(y_t), ag__.ld(y_p), ag__.ld(sw)), None, fscope)
# ---> 72                         sw = ag__.converted_call(ag__.ld(apply_mask), (ag__.ld(y_p), ag__.ld(sw), ag__.converted_call(ag__.ld(get_mask), (ag__.ld(y_p),), None, fscope)), None, fscope)
#      73                         loss_value = ag__.converted_call(ag__.ld(loss_obj), (ag__.ld(y_t), ag__.ld(y_p)), dict(sample_weight=ag__.ld(sw)), fscope)
#      74                         loss_metric_value = ag__.ld(loss_value)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     430   try:
#     431     program_ctx = converter.ProgramContext(options=options)
# --> 432     converted_f = _convert_actual(target_entity, program_ctx)
#     433     if logging.has_verbosity(2):
#     434       _log_callargs(converted_f, effective_args, kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _convert_actual(entity, program_ctx)
#     272                      ' try passing f.python_function instead.')
#     273
# --> 274   transformed, module, source_map = _TRANSPILER.transform(entity, program_ctx)
#     275
#     276   assert not hasattr(transformed, 'ag_module')
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform(self, obj, user_context)
#     284     """
#     285     if inspect.isfunction(obj) or inspect.ismethod(obj):
# --> 286       return self.transform_function(obj, user_context)
#     287
#     288     raise NotImplementedError('Non-function: {}'.format(type(obj)))
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform_function(self, fn, user_context)
#     488           factory = _PythonFnFactory(
#     489               ctx.info.name, fn.__code__.co_freevars, self.get_extra_locals())
# --> 490           factory.create(
#     491               nodes, ctx.namer, future_features=ctx.info.future_features)
#     492           self._cache[fn][cache_subkey] = factory
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in create(self, nodes, namer, inner_factory_name, outer_factory_name, future_features)
#     177     inner_factory_name = namer.new_symbol(inner_factory_name, ())
#     178     outer_factory_name = namer.new_symbol(outer_factory_name, ())
# --> 179     nodes = _wrap_into_factory(nodes, self._name, inner_factory_name,
#     180                                outer_factory_name, self._freevars,
#     181                                self._extra_locals.keys(), future_features)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in _wrap_into_factory(nodes, entity_name, inner_factory_name, outer_factory_name, closure_vars, factory_args, future_features)
#     134       return inner_factory_name
#     135   """
# --> 136   return templates.replace(
#     137       template,
#     138       dummy_closure_defs=dummy_closure_defs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in replace(template, **replacements)
#     268   results = []
#     269   for node in nodes:
# --> 270     node = ReplaceTransformer(replacements).visit(node)
#     271     if isinstance(node, (list, tuple)):
#     272       results.extend(node)
#
# ~/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in visit_FunctionDef(self, node)
#     171
#     172   def visit_FunctionDef(self, node):
# --> 173     node = self.generic_visit(node)
#     174     if node.name not in self.replacements:
#     175       return node
#
# ~/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in visit_FunctionDef(self, node)
#     171
#     172   def visit_FunctionDef(self, node):
# --> 173     node = self.generic_visit(node)
#     174     if node.name not in self.replacements:
#     175       return node
#
# ~/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in visit_Expr(self, node)
#     147     # When replacing a placeholder with an entire statement, the replacement
#     148     # must stand on its own and not be wrapped in an Expr.
# --> 149     new_value = self.visit(node.value)
#     150     if new_value is node.value:
#     151       return node
#
# ~/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in visit_Name(self, node)
#     199       return node
#     200
# --> 201     new_nodes = self._prepare_replacement(node, node.id)
#     202
#     203     if not new_nodes:
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in _prepare_replacement(self, replaced, key)
#     138     repl = self.replacements[key]
#     139
# --> 140     new_nodes = ast_util.copy_clean(repl, preserve_annos=self.preserved_annos)
#     141     if isinstance(new_nodes, gast.AST):
#     142       new_nodes = [new_nodes]
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy_clean(node, preserve_annos)
#      74     ast.AST
#      75   """
# ---> 76   return CleanCopier(preserve_annos).copy(node)
#      77
#      78
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      52     for f in node._fields:
#      53       if not f.startswith('__') and hasattr(node, f):
# ---> 54         new_fields[f] = self.copy(getattr(node, f))
#      55     new_node = type(node)(**new_fields)
#      56
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      39
#      40     if isinstance(node, list):
# ---> 41       return [self.copy(n) for n in node]
#      42     elif isinstance(node, tuple):
#      43       return tuple(self.copy(n) for n in node)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in <listcomp>(.0)
#      39
#      40     if isinstance(node, list):
# ---> 41       return [self.copy(n) for n in node]
#      42     elif isinstance(node, tuple):
#      43       return tuple(self.copy(n) for n in node)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      52     for f in node._fields:
#      53       if not f.startswith('__') and hasattr(node, f):
# ---> 54         new_fields[f] = self.copy(getattr(node, f))
#      55     new_node = type(node)(**new_fields)
#      56
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      39
#      40     if isinstance(node, list):
# ---> 41       return [self.copy(n) for n in node]
#      42     elif isinstance(node, tuple):
#      43       return tuple(self.copy(n) for n in node)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in <listcomp>(.0)
#      39
#      40     if isinstance(node, list):
# ---> 41       return [self.copy(n) for n in node]
#      42     elif isinstance(node, tuple):
#      43       return tuple(self.copy(n) for n in node)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      52     for f in node._fields:
#      53       if not f.startswith('__') and hasattr(node, f):
# ---> 54         new_fields[f] = self.copy(getattr(node, f))
#      55     new_node = type(node)(**new_fields)
#      56
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      52     for f in node._fields:
#      53       if not f.startswith('__') and hasattr(node, f):
# ---> 54         new_fields[f] = self.copy(getattr(node, f))
#      55     new_node = type(node)(**new_fields)
#      56
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      39
#      40     if isinstance(node, list):
# ---> 41       return [self.copy(n) for n in node]
#      42     elif isinstance(node, tuple):
#      43       return tuple(self.copy(n) for n in node)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in <listcomp>(.0)
#      39
#      40     if isinstance(node, list):
# ---> 41       return [self.copy(n) for n in node]
#      42     elif isinstance(node, tuple):
#      43       return tuple(self.copy(n) for n in node)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/ast_util.py in copy(self, node)
#      53       if not f.startswith('__') and hasattr(node, f):
#      54         new_fields[f] = self.copy(getattr(node, f))
# ---> 55     new_node = type(node)(**new_fields)
#      56
#      57     if self.preserve_annos:
#
# ~/anaconda3/lib/python3.8/site-packages/gast/gast.py in create_node(self, *args, **kwargs)
#      22         for argname, argval in zip(self._fields, args):
#      23             setattr(self, argname, argval)
# ---> 24         for argname, argval in kwargs.items():
#      25             assert argname in Fields, \
#      26                     "Invalid Keyword argument for {}: {}".format(Name, argname)
#
# KeyboardInterrupt:

# %%
model.evaluate(test_images, test_labels)[1]
# Out:
# 10000/10000 [==============================] - 2s 169us/step
# 0.9932000041007996
